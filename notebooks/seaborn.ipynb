# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot  as plt

# %%
df = pd.read_csv('../data/dm_office_sales.csv')

# %%
df
# Out:
#               division  level of education  training level  work experience  \
# 0             printers        some college               2                6
# 1             printers  associate's degree               2               10
# 2          peripherals         high school               0                9
# 3      office supplies  associate's degree               2                5
# 4      office supplies         high school               1                5
# ..                 ...                 ...             ...              ...
# 995  computer hardware  associate's degree               1                1
# 996  computer software  associate's degree               1                0
# 997        peripherals  associate's degree               2                8
# 998        peripherals  associate's degree               2                3
# 999  computer hardware        some college               0                9
#
#      salary   sales
# 0     91684  372302
# ...

# %%
sns.scatterplot(data=df, x='salary', y='sales', s=200,alpha=0.7, style='level of education', hue='level of education')
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %%
plt.figure(figsize=(10,5))
sns.rugplot(x='salary', data=df, height=0.5)
# Out:
# <AxesSubplot:xlabel='salary'>

# %%
sns.set(style='dark')
sns.displot(data=df, x='salary', bins=30, color='red', edgecolor='blue')

# %%
sns.histplot(data=df, x='salary', kde=True)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Count'>

# %%
np.random.seed(42)
sample = np.random.randint(0,100,200)

# %%
sample
# Out:
# array([51, 92, 14, 71, 60, 20, 82, 86, 74, 74, 87, 99, 23,  2, 21, 52,  1,
#        87, 29, 37,  1, 63, 59, 20, 32, 75, 57, 21, 88, 48, 90, 58, 41, 91,
#        59, 79, 14, 61, 61, 46, 61, 50, 54, 63,  2, 50,  6, 20, 72, 38, 17,
#         3, 88, 59, 13,  8, 89, 52,  1, 83, 91, 59, 70, 43,  7, 46, 34, 77,
#        80, 35, 49,  3,  1,  5, 53,  3, 53, 92, 62, 17, 89, 43, 33, 73, 61,
#        99, 13, 94, 47, 14, 71, 77, 86, 61, 39, 84, 79, 81, 52, 23, 25, 88,
#        59, 40, 28, 14, 44, 64, 88, 70,  8, 87,  0,  7, 87, 62, 10, 80,  7,
#        34, 34, 32,  4, 40, 27,  6, 72, 71, 11, 33, 32, 47, 22, 61, 87, 36,
#        98, 43, 85, 90, 34, 64, 98, 46, 77,  2,  0,  4, 89, 13, 26,  8, 78,
#        14, 89, 41, 76, 50, 62, 95, 51, 95,  3, 93, 22, 14, 42, 28, 35, 12,
#        31, 70, 58, 85, 27, 65, 41, 44, 61, 56,  5, 27, 27, 43, 83, 29, 61,
#        74, 91, 88, 61, 96,  0, 26, 61, 76,  2, 69, 71, 26])

# %%
sample_ages = pd.DataFrame(sample,columns=['age'])

# %%
sample_ages
# Out:
#      age
# 0     51
# 1     92
# 2     14
# 3     71
# 4     60
# ..   ...
# 195   76
# 196    2
# 197   69
# 198   71
# 199   26
#
# [200 rows x 1 columns]

# %%
sns.rugplot(data=sample_ages)
# Out:
# <AxesSubplot:>

# %%
sns.displot(data=sample_ages, x='age', rug=True, bins=10)

# %%
df['division'].value_counts()
# Out:
# office supplies      252
# printers             250
# peripherals          243
# computer hardware    159
# computer software     96
# Name: division, dtype: int64

# %%
plt.figure(figsize=(10,5), dpi=200)
sns.countplot(data=df, x='level of education', hue='division')
# Out:
# <AxesSubplot:xlabel='level of education', ylabel='count'>

# %%
sns.barplot(data=df, x='level of education', y='salary', estimator=np.mean,ci='sd',hue='division')
plt.legend(bbox_to_anchor=(1.05,1))

# %%
#------------------------------------------

# %%
df = pd.read_csv('../data/StudentsPerformance.csv')

df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
plt.figure(figsize=(10,4), dpi=200)
sns.boxplot(data=df, y='math score', x='parental level of education',hue='test preparation course')

plt.legend(bbox_to_anchor=(1.05,0.5))

# %%
plt.figure(figsize=(15,15), dpi=200)
sns.violinplot(data=df, x='math score', y='parental level of education',hue='test preparation course', split=True)
# Out:
# <AxesSubplot:xlabel='math score', ylabel='parental level of education'>

# %%
plt.figure(figsize=(10,5), dpi=200)
sns.swarmplot(data=df, x='math score',y='gender' ,size=2, hue='test preparation course', dodge=True)
plt.legend(bbox_to_anchor=(1.05,0.5))

# %%
sns.boxenplot(data=df, x='math score', y='test preparation course', hue='gender')
# Out:
# <AxesSubplot:xlabel='math score', ylabel='test preparation course'>

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
sns.jointplot(data=df, x='math score', y='reading score', kind = 'hist', alpha=0.2, hue='gender')

# %%
sns.pairplot(data=df, hue='gender')

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
sns.catplot(data=df, x='gender', y='math score', kind = 'box',
            col = 'lunch')

# %%
g=sns.PairGrid(df, hue='gender')

g= g.map_upper(sns.scatterplot)

g= g.map_diag(sns.histplot)

g = g.map_lower(sns.kdeplot)

g = g.add_legend()

# %%
df = pd.read_csv('../data/population_by_country_2020.csv')

# %%
df.head()
# Out:
#   Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                   China         1440297825        0.39 %     5540090
# 1                   India         1382345085        0.99 %    13586631
# 2           United States          331341050        0.59 %     1937734
# 3               Indonesia          274021604        1.07 %     2898047
# 4                Pakistan          221612785        2.00 %     4327022
#
#    Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0              153          9388211       -348399.0        1.7       38
# 1              464          2973190       -532687.0        2.2       28
# 2               36          9147420        954806.0        1.8       38
# 3              151          1811570        -98955.0        2.3       30
# 4              287           770880       -233379.0        3.6       23
#
#   Urban Pop % World Share
# 0        61 %     18.47 %
# 1        35 %     17.70 %
# ...

# %%
df = df.set_index('Country (or dependency)')

# %%
df.head()
# Out:
#                          Population (2020) Yearly Change  Net Change  \
# Country (or dependency)
# China                           1440297825        0.39 %     5540090
# India                           1382345085        0.99 %    13586631
# United States                    331341050        0.59 %     1937734
# Indonesia                        274021604        1.07 %     2898047
# Pakistan                         221612785        2.00 %     4327022
#
#                          Density (P/Km²)  Land Area (Km²)  Migrants (net)  \
# Country (or dependency)
# China                                153          9388211       -348399.0
# India                                464          2973190       -532687.0
# United States                         36          9147420        954806.0
# Indonesia                            151          1811570        -98955.0
# Pakistan                             287           770880       -233379.0
#
# ...

# %%
df = df[['Net Change', 'Land Area (Km²)']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 235 entries, China to Holy See
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Net Change       235 non-null    int64
#  1   Land Area (Km²)  235 non-null    int64
# dtypes: int64(2)
# memory usage: 5.5+ KB

# %%
sns.heatmap(df, cmap='viridis')
# Out:
# <AxesSubplot:ylabel='Country (or dependency)'>

# %%
#------------------------------

# %%
df = pd.read_csv('../data/application_record.csv')

# %%
df.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %%
employed = df[df['DAYS_EMPLOYED']<0]

# %%
employed['DAYS_EMPLOYED'] = employed['DAYS_EMPLOYED']*-1
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_9900\128320624.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   employed['DAYS_EMPLOYED'] = employed['DAYS_EMPLOYED']*-1

# %%
employed['DAYS_BIRTH'] = employed['DAYS_BIRTH']*-1
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_9900\3255079613.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   employed['DAYS_BIRTH'] = employed['DAYS_BIRTH']*-1

# %%
plt.figure(figsize=(10,5), dpi=200)
sns.scatterplot(data=employed, y='DAYS_EMPLOYED', x='DAYS_BIRTH', alpha=0.01, linewidth=0)
# Out:
# <AxesSubplot:xlabel='DAYS_BIRTH', ylabel='DAYS_EMPLOYED'>

# %%
df['YEARS'] = -1*df['DAYS_BIRTH']/365
sns.histplot(data=df, x='YEARS', bins=48, color='red')
# Out:
# <AxesSubplot:xlabel='YEARS', ylabel='Count'>

# %%
int(len(df)/2)
# Out:
# 219278

# %%
botom_half = df.nsmallest(n=219278, columns='AMT_INCOME_TOTAL')

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=botom_half, y='AMT_INCOME_TOTAL', x='NAME_FAMILY_STATUS', hue='FLAG_OWN_REALTY')
plt.legend(loc=(1.05,0.5))

# %%
df.corr()
# Out:
#                         ID  CNT_CHILDREN  AMT_INCOME_TOTAL  DAYS_BIRTH  \
# ID                1.000000     -0.005178          0.011179   -0.004994
# CNT_CHILDREN     -0.005178      1.000000          0.019177    0.349088
# AMT_INCOME_TOTAL  0.011179      0.019177          1.000000    0.053775
# DAYS_BIRTH       -0.004994      0.349088          0.053775    1.000000
# DAYS_EMPLOYED    -0.002467     -0.241535         -0.141291   -0.617908
# FLAG_MOBIL             NaN           NaN               NaN         NaN
# FLAG_WORK_PHONE  -0.023319      0.038418         -0.033635    0.171829
# FLAG_PHONE       -0.018992     -0.038266          0.004444   -0.037984
# FLAG_EMAIL        0.032875      0.028457          0.112139    0.096752
# CNT_FAM_MEMBERS  -0.001862      0.884781          0.011454    0.306179
# YEARS             0.004994     -0.349088         -0.053775   -1.000000
#
#                   DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  \
# ...

# %%
sns.heatmap(df.drop('FLAG_MOBIL', axis=1).corr(),cmap='viridis')
# Out:
# <AxesSubplot:>
